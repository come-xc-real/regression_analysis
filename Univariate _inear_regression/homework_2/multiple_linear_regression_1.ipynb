# %%
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd

data = pd.read_csv("t3.5.csv", sep=" ")
data = np.array(data)
# data = data.transpose()
data

# %%
# 导入所需的库
import numpy as np
import statsmodels.api as sm

X = sm.add_constant(data[:,1:])
y = data[:, 0]
model = sm.OLS(y, X)
results = model.fit()
print("Model coefficients:", results.params)
print("Intercept:", results.params[0])
print("ANOVA table:")
print(results.summary())
# Out:
# Model coefficients: [-57.4549599   45.70558193  11.93339301]
# Intercept: -57.45495989842226
# ANOVA table:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.904
# Model:                            OLS   Adj. R-squared:                  0.890
# Method:                 Least Squares   F-statistic:                     65.84
# Date:                Sun, 24 Mar 2024   Prob (F-statistic):           7.57e-08
# Time:                        17:36:35   Log-Likelihood:                -93.195
# No. Observations:                  17   AIC:                             192.4
# Df Residuals:                      14   BIC:                             194.9
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -57.4550     81.022     -0.709      0.490    -231.230     116.320
# x1            45.7056     15.669      2.917      0.011      12.099      79.312
# x2            11.9334      1.517      7.869      0.000       8.681      15.186
# ==============================================================================
# Omnibus:                        6.484   Durbin-Watson:                   2.104
# Prob(Omnibus):                  0.039   Jarque-Bera (JB):                3.604
# Skew:                           0.870   Prob(JB):                        0.165
# Kurtosis:                       4.434   Cond. No.                         163.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# G:\github_project\github_me\regression_analysis_project\python_env\lib\site-packages\scipy\stats\_stats_py.py:1971: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=17
#   k, _ = kurtosistest(a, axis)

# %%
import matplotlib
matplotlib.rcParams['axes.unicode_minus']=False
# 创建窗口
fig=plt.figure()
# 在该窗口中创建3d绘图对象
ax=Axes3D(fig)
fig.add_axes(ax)
ax.scatter(data[:,1], data[:,2], data[:,0])
x_1= [3, 8]
x_2 = [10, 48]
y = [results.params[0] + results.params[1] * 3 + results.params[2] * 10,
     results.params[0] + results.params[1] * 8 + results.params[2] * 48]

ax.plot(x_1, x_2, y, color='blue', linestyle='-')

# 添加坐标轴(顺序是Z, Y, X)
ax.set_zlabel('Y', fontdict={'size': 15, 'color': 'red'})
ax.set_ylabel('x_1', fontdict={'size': 15, 'color': 'red'})
ax.set_xlabel('x_2', fontdict={'size': 15, 'color': 'red'})

plt.show()

# %%
# predictions = results.predict([[1, 67, 58]])
# prediction = results.get_prediction([[1, 67, 58]])
# print("Predictions:", predictions)
# print("Prediction Interval:\n", prediction.summary_frame(alpha=0.05))
